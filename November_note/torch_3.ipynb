# %%
import torch
import numpy as np
import pandas as pd
import os

# %%
a = torch.ones(2,3)
b = torch.cos(a)

print(a)
print(b)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# tensor([[0.5403, 0.5403, 0.5403],
#         [0.5403, 0.5403, 0.5403]])
